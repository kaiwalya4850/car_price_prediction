# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("data_main.csv")

data.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# 2                Luxury,High-Performance      Compact         Coupe
# 3                     Luxury,Performance      Compact         Coupe
# 4                                 Luxury      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %%
data.dropna(inplace=True,axis=0)
data.isnull().sum()
# Out:
# Make                 0
# Model                0
# Year                 0
# Engine Fuel Type     0
# Engine HP            0
# Engine Cylinders     0
# Transmission Type    0
# Driven_Wheels        0
# Number of Doors      0
# Market Category      0
# Vehicle Size         0
# Vehicle Style        0
# highway MPG          0
# city mpg             0
# Popularity           0
# MSRP                 0
# dtype: int64

# %%
data['new msrp'] = np.log1p(data.MSRP)
data.drop('MSRP', axis=1, inplace=True)

# %%
data.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# 2                Luxury,High-Performance      Compact         Coupe
# 3                     Luxury,Performance      Compact         Coupe
# 4                                 Luxury      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   new msrp
# 0           26        19        3916  10.739349
# 1           28        19        3916  10.612779
# 2           28        20        3916  10.500977
# 3           28        18        3916  10.290483
# 4           28        18        3916  10.448744

# %%
q1, q3 = np.percentile(data['Popularity'],[25,75])
iqr = q3-q1
whisker = q3 + (1.5 * iqr)
data['Popularity'] = data['Popularity'].clip(upper=whisker)

# %%
columns_to_convert=['Make','Model','Engine Fuel Type','Transmission Type','Driven_Wheels','Market Category','Vehicle Size','Vehicle Style']
data[columns_to_convert] = data[columns_to_convert].astype('category')

# %%
from sklearn import preprocessing
  
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column 'species'.
for col in ['Make','Model','Engine Fuel Type','Transmission Type','Driven_Wheels','Market Category','Vehicle Size','Vehicle Style']: data[col] = label_encoder.fit_transform(data[col])

data.head()
# Out:
#    Make  Model  Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# 0     4      1  2011                 6      335.0               6.0
# 1     4      0  2011                 6      300.0               6.0
# 2     4      0  2011                 6      300.0               6.0
# 3     4      0  2011                 6      230.0               6.0
# 4     4      0  2011                 6      230.0               6.0
#
#    Transmission Type  Driven_Wheels  Number of Doors  Market Category  \
# 0                  3              3              2.0               37
# 1                  3              3              2.0               66
# 2                  3              3              2.0               63
# 3                  3              3              2.0               66
# 4                  3              3              2.0               62
#
#    Vehicle Size  Vehicle Style  highway MPG  city mpg  Popularity   new msrp
# 0             0              8           26        19        3916  10.739349
# 1             0              6           28        19        3916  10.612779
# 2             0              8           28        20        3916  10.500977
# 3             0              8           28        18        3916  10.290483
# 4             0              6           28        18        3916  10.448744

# %%
import seaborn as sns
corrmat = data.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(13,13))
g=sns.heatmap(data[top_corr_features].corr(),annot=True,cmap='rainbow',linewidths=3)

# %%
X = data.corr()
X['new msrp'].sort_values(ascending=False)
# Out:
# new msrp             1.000000
# Engine HP            0.705369
# Year                 0.658258
# Engine Cylinders     0.496731
# Vehicle Size         0.117713
# Vehicle Style        0.086207
# Model                0.062594
# Popularity           0.028981
# Number of Doors     -0.040657
# Driven_Wheels       -0.100777
# Market Category     -0.134591
# highway MPG         -0.179530
# Make                -0.186651
# city mpg            -0.208235
# Engine Fuel Type    -0.229984
# Transmission Type   -0.307729
# Name: new msrp, dtype: float64

# %%
New_data = data.copy()
xyz = ['new msrp','Engine HP','Year','Engine Cylinders','Transmission Type','Engine Fuel Type','city mpg','Make','highway MPG','Market Category','Driven_Wheels']
data_all = New_data[xyz]
data_all.head()
# Out:
#     new msrp  Engine HP  Year  Engine Cylinders  Transmission Type  \
# 0  10.739349      335.0  2011               6.0                  3
# 1  10.612779      300.0  2011               6.0                  3
# 2  10.500977      300.0  2011               6.0                  3
# 3  10.290483      230.0  2011               6.0                  3
# 4  10.448744      230.0  2011               6.0                  3
#
#    Engine Fuel Type  city mpg  Make  highway MPG  Market Category  \
# 0                 6        19     4           26               37
# 1                 6        19     4           28               66
# 2                 6        20     4           28               63
# 3                 6        18     4           28               66
# 4                 6        18     4           28               62
#
#    Driven_Wheels
# 0              3
# 1              3
# 2              3
# 3              3
# 4              3

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import metrics
#data

var = ['new msrp','Engine HP','Year','Engine Cylinders','Transmission Type','Engine Fuel Type','city mpg','Make','highway MPG','Market Category','Driven_Wheels']
data_for_decision_tree = New_data[var]
data_for_decision_tree.head()


# dcoupling

data =data_for_decision_tree
target = "new msrp"

X = data[data.columns.difference([target])]
y = data['new msrp']

#Train test spilt

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=124421)

# Fit regression model
regr_2 = DecisionTreeRegressor(max_depth=4)
regr_2.fit(X_train, y_train)
y_pred2 = regr_2.predict(X_test)
# Out:
# 5580     10.942987
# 3254     10.962510
# 8007      9.774290
# 883       7.601402
# 6708      7.601402
#            ...
# 11469    10.192269
# 8893     10.568775
# 5696     10.671997
# 5101     10.595409
# 11240     9.857496
# Name: new msrp, Length: 1617, dtype: float64

# %%
print('These were the actual values: ',y_test)
print('These are predicted values: ',y_pred2) 
print('mean_squared_error for max depth 4 =',mean_squared_error(y_test,y_pred2))
print('r2_score max depth 4 =',r2_score(y_test,y_pred2))
print('mean_squared_error sqrt max depth 4 =',np.sqrt(metrics.mean_squared_error(y_test,y_pred2)))
# Out:
# These were the actual values:  5580     10.942987
# 3254     10.962510
# 8007      9.774290
# 883       7.601402
# 6708      7.601402
#            ...
# 11469    10.192269
# 8893     10.568775
# 5696     10.671997
# 5101     10.595409
# 11240     9.857496
# Name: new msrp, Length: 1617, dtype: float64
# These are predicted values:  [10.8392997  10.54486886  9.9859297  ... 10.54486886 10.8392997
#   9.9859297 ]
# mean_squared_error for max depth 4 = 0.07355635477612756
# r2_score max depth 4 = 0.9195340688925882
# mean_squared_error sqrt max depth 4 = 0.271212748181437

# %%
np.expm1(y_pred2[0])
# Out:
# 50984.66011626437
